# %% [markdown]
# # Tasca M1 T01     Ana Belén López

# %% [markdown]
# # EJERCICIO 1:
#
# A partir dels documents adjunts (estructura i dades), crea una base de dades amb MySQL. Mostra les característiques principals de l'esquema creat i explica les diferents taules i variables que hi ha.

# %% [markdown]
# Paso 1: Creamos la base de datos llamada movies y comprobamos que se ha registrado correctamente.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-06%20a%20las%209.54.01.png](attachment:Captura%20de%20pantalla%202022-10-06%20a%20las%209.54.01.png)

# %% [markdown]
# Paso 2: Captura de pantalla del esquema.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-06%20a%20las%2010.54.47.png](attachment:Captura%20de%20pantalla%202022-10-06%20a%20las%2010.54.47.png)

# %% [markdown]
# Paso 3:
#
# Dentro de la Base de Datos Movies, nos encontramos cinco tablas:
# * tb_role
# * tb_movie
# * tb_genre
# * tb_person
# * tb_movieperson
#
# Cada tabla cuenta con una serie de columnas como se ven en el diagrama, dónde encontramos tipo INT, tipo VARCHAR y tipo DATE.

# %% [markdown]
# # EJERCICIO 2:
#
#
# Has d'obtenir el nom, el país i la data de naixement d'aquelles persones per les quals no consti una data de mort i ordenar les dades de la persona més vella a la persona més jove.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2011.06.07.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2011.06.07.png)

# %% [markdown]
# # EJERCICIO 3:
#
# Has d'obtenir el nom del gènere i el nombre total de pel·lícules d'aquest gènere i ordenar-ho per ordre descendent de nombre total de pel·lícules.

# %% [markdown]
# Paso 1: Consultamos los géneros que hay.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2011.09.34.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2011.09.34.png)

# %% [markdown]
# Paso 2: Unimos con un INNER JOIN la tabla géneros con la tabla de películas.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2011.27.13.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2011.27.13.png)

# %% [markdown]
# Paso 3: Utilizamos el Group By para agrupar los géneros y count(1) que nos dará el sumatorio de las películas

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2011.37.41.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2011.37.41.png)

# %% [markdown]
# Paso 4: Ordenamos de mayor a menor

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2011.44.15.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2011.44.15.png)

# %% [markdown]
# # EJERCICIO 4:
#
# Has d'obtenir, per a cada persona, el seu nom i el nombre màxim de rols diferents que ha tingut en una mateixa pel·lícula.
#
# Posteriorment, mostra únicament aquelles persones que hagin assumit més d'un rol en una mateixa pel·lícula.

# %% [markdown]
# Paso 1: Realizamos la consulta.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-17%20a%20las%2021.40.29.png](attachment:Captura%20de%20pantalla%202022-10-17%20a%20las%2021.40.29.png)

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-17%20a%20las%2021.46.09.png](attachment:Captura%20de%20pantalla%202022-10-17%20a%20las%2021.46.09.png)

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-17%20a%20las%2021.54.34.png](attachment:Captura%20de%20pantalla%202022-10-17%20a%20las%2021.54.34.png)

# %% [markdown]
# Paso 2: Seleccionamos a las personas que hayan tenido más de un rol en una misma película.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-17%20a%20las%2022.06.26.png](attachment:Captura%20de%20pantalla%202022-10-17%20a%20las%2022.06.26.png)

# %% [markdown]
# # EJERCICIO 5:
#
# Has de crear un nou gènere anomenat "Documental" el qual tingui com a identificador el nombre 69.
#
# Paso 1: Introducimos la Query que creará el nuevo registro

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.12.17.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.12.17.png)

# %% [markdown]
# Paso 2: Comprobamos que se haya creado correctamente

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.13.58.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.13.58.png)

# %% [markdown]
# # EJERCICIO 6:
#
# Elimina la pel·lícula "La Gran Familia Española" de la base de dades.
#
# Paso 1: Comprobamos que existe en nuestra base de datos la película a borrar

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.20.32.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.20.32.png)

# %% [markdown]
# Paso 2: Eliminamos la película

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.22.12.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.22.12.png)

# %% [markdown]
# # EJERCICIO 7:
#
# Canvia el gènere de la pel·lícula "Ocho apellidos catalanes" perquè consti com a comèdia i no com a romàntica.

# %% [markdown]
# Paso 1: Comprobamos los id de los géneros, ahora sabemos que tenemos que cambiar el ID 8 que pertenece a romance por el 3 que pertenece a comedia.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.32.38.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.32.38.png)

# %% [markdown]
# Paso 2: Comprobamos el id de la película para poder hacer el cambio, ya que por la ocnfiguración del editor no nos deja cambiarlo con el movie-title, precisa del movie_id

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.40.16.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.40.16.png)

# %% [markdown]
# Paso 3: Lanzamos la Query para realizar el cambio

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.40.53.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.40.53.png)

# %% [markdown]
# Paso 4: Comprobamos que el género de la película Ocho Apellidos Catalanes ha sido actualizado con éxito.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-10-15%20a%20las%2012.41.12.png](attachment:Captura%20de%20pantalla%202022-10-15%20a%20las%2012.41.12.png)
